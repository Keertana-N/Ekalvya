# %% [markdown]
# # Semantic Candidate Matching
#
# The goal for this notebook:
#
# - Understand the job description semantically and compare it with every candidate profile using sentence embeddings.
# - Unlike keyword matching, embeddings capture meaning rather than exact words.

# %%
import json
import numpy as np
import pandas as pd

from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
